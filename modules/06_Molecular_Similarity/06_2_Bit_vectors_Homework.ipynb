# %% [markdown]
#  <div class="alert alert-block alert-success">
#       <H1><center>Homework</center></H1>

# %% [markdown]
# ## Problem 1: Comparing fingerprint bit vectors (15 pts)
#
# Obtain the SMILES string for ibuprofen from PubChem programmatically. Write python code to generate:
# 1) MACCS keys using RDKit
# 2) A Morgan Fingerprint with `radius = 2` and `fpSize = 1024`
# 3) A PubChem Fingerprint downloaded from PubChem and converted into an RDKit bit vector.
#
# For each fingerprint, output the following data:
# type(fingerprint)
# fingerprint.GetNumBits()
# sys.getsizeof(fingerprint)

# %%
# write your code here

# %% [markdown]
# Answer the following:
#
# 1) Which fingerprints were created directly as RDKit bit vectors?
# 2) Which fingerprint had to be converted from another format?
# 3) Why is the bit vector more useful than the bit string for molecular similarity calculations?

# %% [raw]
# 1)
#
# 2)
#
# 3)

# %% [markdown]
# ## Problem 2: Inspecting specific bits in a PubChem fingerprint (15 pts)
#
# Using the PubChem fingerprint bit string for ibuprofen, write code to determine whether positions 178, 179, 182, and 184 are set to 1 or 0.
#
# Your output should clearly identify each position, for example: *(note these values are just placeholders and not the actual values)*
#
# Position 178: 1<br>
# Position 179: 0<br>
# Position 182: 1<br>
# Position 184: 1<br>

# %%
# write your code here

# %% [markdown]
# Answer the following:
#
# 1) What does it mean when a fingerprint bit is “on”?
# 2) Why might it be useful to inspect individual bits in a structural-key fingerprint such as the PubChem fingerprint?

# %% [raw]
# 1)
#
# 2)
