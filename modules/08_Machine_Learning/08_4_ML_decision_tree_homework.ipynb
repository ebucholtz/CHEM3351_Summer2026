# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # <center>Homework</center>
#
# (50 pts)

# %% [markdown]
# In this activity you generated decision tree models using MACCS Keys as your structural inputs. Previously, in homework 8_2_fingerprint_generation, you created ECFP4 equivalent circular fingerprints (Morgan fingerprings with 1024 bits and radius set to 2 saved as **AID743169_activity_ECFP.csv**).
#
# Using what you learned in creating the cross validated decision tree classification model using MACCS Keys generate a new classification model using your stored downsampled training and test sets based pm ECFPs from your homework from 08_3_NB_activity.ipynb. To be successful you will need to:
#
# - build a **cross validated decision tree** classification model
# - save the model as using pipeline method with zero variance as `cvdt_ds_ecfp_pipeline_yourinitials.joblib`
# - Save the best parameters to use later as `best_DT_params_ECFP_yourinitials.joblib`
# - output a Confusion matrix for the training and test sets
# - calculate key performance metrics for the training and test sets
# - test the model using the same five molecules that were used in the MACCS model testing
# - evaluate if your ECFP cross validated decision tree does a better job at predicting these five molecules activities vs using MACCS Keys. Add that to a raw cell at the end of this notebook.

# %%
# write your code here. You should use multiple code cells for easier debugging.
