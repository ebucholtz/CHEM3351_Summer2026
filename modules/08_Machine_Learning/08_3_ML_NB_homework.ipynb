# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # <center>Homework</center>
#
# (70 pts)

# %% [markdown]
# In this activity you generated a naïve Bayes classification model using MACCS Keys as your structural inputs. Previously, in homework 8_2_fingerprint_generation, you created ECFP4 equivalent circular fingerprints (Morgan fingerprings with 1024 bits and radius set to 2 saved as **AID743169_activity_ECFP.csv**).
#
# Using what you learned in creating the naïve Bayes classification model using MACCS Keys, generate a new naïve Bayes classification classification model using your stored ECFP4 fingerprints. To be successful you will need to:
#
# - create a 9:1 train-test split
# - balance your training set
# - save a copy of your downsampled X training set with your ECFP4 fingerprints as `X_train_downsampled_ECFP.npy`
# - save a copy of your downsampled y training set with your ECFP4 fingerprints as `y_train_downsampled_ECFP.npy`
# - save a copy of your X test set with your ECFP4 fingerprints as`X_test_ECFP.npy`
# - save a copy of your X test set with your ECFP4 fingerprints as`y_test_ECFP.npy`
# - build a Bernoulli Naïve Bayes classification model using the pipeline method and remove all variables that have zero variance
# - save the model as using pipeline method with zero variance as **nb_ds_ecfp_pipeline_yourinitials.joblib**
# - output a Confusion matrix
# - calculate key perforance metrics or the training set
# - test the model using the same molecules that were used in the MACCS model testing
# - reload the model and test it with the same 5 molecules we used in the activity

# %%
# write your code here. You should use multiple code cells for easier debugging.
