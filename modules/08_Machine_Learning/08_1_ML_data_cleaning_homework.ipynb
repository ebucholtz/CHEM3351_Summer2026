# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # <center>Homework</center>

# %% [markdown]
# You have saved your cleaned data in two csv files. You will reload these into new dataframes and display the first 10 rows of each. (10 pts)

# %%
# Write code for any libraries you need to import

# %%
# Write code to load the saved cleaned activity data into a new datafram called "clean_activity" and display first 10 rows.

# %%
# Write code to load the saved cleaned SMILES data into a new datafram called "clean_smiles" and display last 10 rows.
