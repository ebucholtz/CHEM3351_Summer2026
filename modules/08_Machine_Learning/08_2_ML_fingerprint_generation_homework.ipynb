# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # <center>Homework</center>

# %% [markdown]
# In this activity you generated MACCS Keys for our aromatase dataset. In this homework, rather than generating MACCS Keys, generate the ECFP-equivalent Morgan Fingerprints from the SMILES strings.
#
# - Use RDKit to generate 1024-bit-long circular fingerprints.
# - Set the radius of the circular fingerprint to 2.
# - Store the fingerprints in a data_frame called **df_fps2** (along with the CIDs).
# - Print the dimension of **df_fps2**.
# - Show the first five lines of **df_fps2**.
# - Merge this data with the AID743139_activity_cids.csv data in a new data_frame called **df_data2**, but remove the external datasource smiles
# - Save this dataframe as **AID743169_activity_ECFP.csv** for use later.

# %%
# write your code here. You should use multiple code cells for easier debugging.
