# %% [markdown]
#  <div class="alert alert-block alert-success">
# <H1><center>Homework</center></H1>
#
# (15 pts)
# </div>

# %% [markdown]
# Answer the following questions, based on the analysis of the compounds tested in both rat and human thyroid hormone receptors in `05_2_eda_protein_Activity.ipynb` (i.e., the compounds in the `df_aid_merged_cid` data frame).

# %% [markdown]
# (1) How many compounds were tested against both rat thyroid hormone receptor?

# %% [raw]
# # Provide your answer here

# %% [markdown]
# (2) Among the compounds tested in both species, how many were active against **rat** thyroid hormone receptor?

# %% [raw]
# # Provide your answer here

# %% [markdown]
# (3) Among the compounds active in rats (i.e., those in (2)), how many were active against **human** thyroid hormone receptor?

# %% [raw]
# # Provide your answer here

# %% [markdown]
# (4) Recall at the start of this activity we had an underlying assumption that the bioactivity (e.g., toxicity and efficacy) of a drug candidate in animals is similar to its activity in humans. Based on your answer to (3), can you confidently say there is a definitive relationship between rat and human data for activity at this receptor? Explain

# %% [raw]
# # Provide your answer here

# %% [markdown]
# (5) Read the following paper (open access, link below) on the concordance of the toxicity of drugs between animals and humans and summarize its main points.
#
# **<a href = "https://www.jacc.org/doi/10.1016/j.jacbts.2019.10.008"> Limitations of Animal Studies for Predicting Toxicity in Clinical Trials: Is it Time to Rethink Our Current Approach?</a>**
# Van Norman GA.
# JACC Basic Transl Sci. 2019 Nov 25;4(7):845-854.
# doi: **[10.1016/j.jacbts.2019.10.008](https://doi.org/10.1016/j.jacbts.2019.10.008)**. PMID: 31998852; PMCID: PMC6978558.

# %% [raw]
# Write your summary in this cell:
