# %% [markdown]
# # My First Notebook!

# %% [markdown]
# ##### My First Notebook!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
my_var = "Hello, World"
var1 = "Hello"
var2 = "World"
var3 = 3

# %%
print(my_var)
# Out:
# Hello, World

# %%
print(var1,var2)
# Out:
# Hello World

# %%
# concatenation
print(var1+var2)
# Out:
# HelloWorld

# %%
print(var1 + ", " + var2 +"!")
# Out:
# Hello, World!

# %%
print(var1 + var3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(var1 + var3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(var3)
# Out:
# int

# %%
print(var1 + str(var3))
# Out:
# Hello3

# %%
type(var3)
# Out:
# int

# %%
var4=1.32
print(type(var4))
# Out:
# <class 'float'>

# %%
print(var3+var4)
# Out:
# 4.32

# %%
type(var1)
# Out:
# str

# %%
my_list = ["Ehren", "Aubrey","Preston","Hannah", "Adhira"]

# %%
print(my_list)
# Out:
# ['Ehren', 'Aubrey', 'Preston', 'Hannah', 'Adhira']

# %%
print(' '.join(my_list))
# Out:
# Ehren Aubrey Preston Hannah Adhira

# %%
print(my_list[1])
# Out:
# Aubrey

# %%
print(my_list[0])
# Out:
# Ehren

# %%
print(my_list[4])
# Out:
# Adhira

# %%
print(my_list[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(my_list[5])
#
# IndexError: list index out of range

# %%
for item in my_list:
    print(item)
# Out:
# Ehren
# Aubrey
# Preston
# Hannah
# Adhira

# %%
my_other_list =[1,2,3,4]

# %%
for number in my_other_list:
    print(number)
# Out:
# 1
# 2
# 3
# 4

# %%
for garbage in my_other_list:
    print(garbage)
# Out:
# 1
# 2
# 3
# 4

# %%
for garbage in my_other_list:
    print(garbage*3)
# Out:
# 3
# 6
# 9
# 12

# %%
for garbage in my_list:
    print(garbage*3)
# Out:
# EhrenEhrenEhren
# AubreyAubreyAubrey
# PrestonPrestonPreston
# HannahHannahHannah
# AdhiraAdhiraAdhira

# %%
if var3> 4:
    print(str(var3)+ "is greater than 4")
else:
    print(str(var3)+ "is not greater than 4")
# Out:
# 3is not greater than 4

# %%
# built in function
# print() is a built in function
import random
print("random float:", random.random())
# Out:
# random float: 0.8956753142212995

# %%
# built in function
# print() is a built in function
import random
print("random float:", random.random())
# Out:
# random float: 0.2860172200880928

# %%
# built in function
# print() is a built in function
import random
print("random float:", random.random())
# Out:
# random float: 0.21933501783106402
