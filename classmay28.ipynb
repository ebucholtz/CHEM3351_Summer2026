# %%
import requests

# %%
response = requests.get("https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/4488/property/HBondAcceptorCount/txt")

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# 7

# %%
pugrest = "https://pubchem.ncbi.nlm.nih.gov/rest/pug"
pugin   = "compound/name/water"
pugoper = "property/MolecularFormula"
pugout  = "txt"

url     = pugrest + '/' + pugin + '/' + pugoper + '/' + pugout

print(url)
# Out:
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/water/property/MolecularFormula/txt

# %%
res = requests.get(url)

# %%
print(res.text)
# Out:
# H2O

# %%
ourlist= [2234,234,25145,234143]
